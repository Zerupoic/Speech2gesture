# %%
import numpy as np
import matplotlib.pyplot as plt

LOSS_PATH = './save/loss_almaram_norm.npy'

loss_list = np.load(LOSS_PATH)
# print(loss_list)

itr = np.arange(200, 200 * (loss_list.shape[1] + 1), 200)

if itr.size != loss_list.size / 2:
    print('size problem!')
    exit(0)

# l1 = plt.plot(itr, loss_list[0, :], 'r--', label='generator loss')
# l2 = plt.plot(itr, loss_list[1, :], 'g--', label='discriminator loss')
# plt.plot(itr, loss_list[0, :], 'ro', itr, loss_list[1, :], 'g+-')
# plt.show()

# %%
plt.plot(itr, loss_list[0, :], 'g+-')
plt.title('generator loss')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()

# %%
plt.plot(itr, loss_list[1, :], 'b+-')
plt.title('discriminator loss')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()

# %%
plt.plot(itr, loss_list[0, :], 'g+-')
plt.title('generator loss')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()

# %%
plt.plot(itr, loss_list[1, :], 'b+-')
plt.title('discriminator loss')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()

# %%
plt.plot(itr, loss_list[0, :], 'g+-')
plt.title('generator loss')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()

# %%
plt.plot(itr, loss_list[1, :], 'b+-')
plt.title('discriminator loss')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()
